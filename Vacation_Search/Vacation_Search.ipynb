# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0  Punta Arenas      CL -53.1500  -70.9167     39.31        81
# 1        1        Castro      BR -24.7911  -50.0119     58.03        96
# 2        2         Ginir      ET   7.1333   40.7000     59.23        74
# 3        3   Pangnirtung      CA  66.1451  -65.7125     42.80        87
# 4        4        Kodiak      US  57.7900 -152.4072     56.71        72
#
#    Cloudiness  Wind Speed Current Description
# 0          40       27.63    scattered clouds
# 1         100        5.03          light rain
# 2          79        8.10       broken clouds
# 3          75       13.80       broken clouds
# 4          20        6.91          few clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID           City Country      Lat       Lng  Max Temp  Humidity  \
# 8         8           Naze      JP  28.3667  129.4833     79.72        88
# 19       19   La Primavera      CO   5.4906  -70.4092     78.58        83
# 22       22        Damghan      IR  36.1683   54.3480     88.72        13
# 33       33        Batalha      BR  -9.6778  -37.1247     80.58        67
# 34       34  Kota Kinabalu      MY   5.9749  116.0724     78.78        89
# 35       35    Salinopolis      BR  -0.6136  -47.3561     82.72        74
# 38       38         Atuona      PF  -9.8000 -139.0333     78.17        64
# 41       41        Kavieng      PG  -2.5744  150.7967     82.53        75
# 44       44         Touros      BR  -5.1989  -35.4608     82.44        64
# 45       45         Faanui      PF -16.4833 -151.7500     77.20        66
#
#     Cloudiness  Wind Speed Current Description
# 8          100       17.72     overcast clouds
# 19          99        4.97       moderate rain
# 22           0        7.61           clear sky
# 33          42       12.77    scattered clouds
# 34          20        3.44          light rain
# 35          42       14.74    scattered clouds
# 38          77       18.39       broken clouds
# 41         100       14.61     overcast clouds
# 44          41       15.97    scattered clouds
# 45          30       10.51    scattered clouds

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# City_ID                259
# City                   259
# Country                258
# Lat                    259
# Lng                    259
# Max Temp               259
# Humidity               259
# Cloudiness             259
# Wind Speed             259
# Current Description    259
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)].dropna()
preferred_cities_df.head(10)
# Out:
#     City_ID           City Country      Lat       Lng  Max Temp  Humidity  \
# 8         8           Naze      JP  28.3667  129.4833     79.72        88
# 19       19   La Primavera      CO   5.4906  -70.4092     78.58        83
# 22       22        Damghan      IR  36.1683   54.3480     88.72        13
# 33       33        Batalha      BR  -9.6778  -37.1247     80.58        67
# 34       34  Kota Kinabalu      MY   5.9749  116.0724     78.78        89
# 35       35    Salinopolis      BR  -0.6136  -47.3561     82.72        74
# 38       38         Atuona      PF  -9.8000 -139.0333     78.17        64
# 41       41        Kavieng      PG  -2.5744  150.7967     82.53        75
# 44       44         Touros      BR  -5.1989  -35.4608     82.44        64
# 45       45         Faanui      PF -16.4833 -151.7500     77.20        66
#
#     Cloudiness  Wind Speed Current Description
# 8          100       17.72     overcast clouds
# 19          99        4.97       moderate rain
# 22           0        7.61           clear sky
# 33          42       12.77    scattered clouds
# 34          20        3.44          light rain
# 35          42       14.74    scattered clouds
# 38          77       18.39       broken clouds
# 41         100       14.61     overcast clouds
# 44          41       15.97    scattered clouds
# 45          30       10.51    scattered clouds

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = None
hotel_df.head(10)
# Out:
#              City Country  Max Temp Current Description      Lat       Lng  \
# 8            Naze      JP     79.72     overcast clouds  28.3667  129.4833
# 19   La Primavera      CO     78.58       moderate rain   5.4906  -70.4092
# 22        Damghan      IR     88.72           clear sky  36.1683   54.3480
# 33        Batalha      BR     80.58    scattered clouds  -9.6778  -37.1247
# 34  Kota Kinabalu      MY     78.78          light rain   5.9749  116.0724
# 35    Salinopolis      BR     82.72    scattered clouds  -0.6136  -47.3561
# 38         Atuona      PF     78.17       broken clouds  -9.8000 -139.0333
# 41        Kavieng      PG     82.53     overcast clouds  -2.5744  150.7967
# 44         Touros      BR     82.44    scattered clouds  -5.1989  -35.4608
# 45         Faanui      PF     77.20    scattered clouds -16.4833 -151.7500
#
#    Hotel Name
# 8        None
# 19       None
# 22       None
# 33       None
# 34       None
# 35       None
# 38       None
# 41       None
# 44       None
# 45       None

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key,
    "location" : ""
}

# 6b. Iterate through the hotel DataFrame.
print("---------------Searching for hotels at preferred locations----------------")
for index, row in hotel_df.iterrows():

    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    
    #Adding lat and lng
    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
   
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_name = hotels["results"][0]["name"]
        hotel_df.loc[index, "Hotel Name"] = hotel_name
        city = hotel_df.loc[index, "City"]
        print(f"Found {hotel_name} near {city}.")
    except (IndexError):
        print(f"Hotel not found... skipping {city}... skipping.")
# Out:
# ---------------Searching for hotels at preferred locations----------------
# Found Shishime Hotel near Naze.
# Found La Riviera Hotel Colonial near La Primavera.
# Found خوابگاه اساتيد دانشگاه دامغان near Damghan.
# Found Pousada Solar do Sertão near Batalha.
# Found Gaya Centre Hotel near Kota Kinabalu.
# Found Salinas Park Resort Maçarico AP101 near Salinopolis.
# Found Villa Enata near Atuona.
# Found Nusa Island Retreat near Kavieng.
# Found INN NEW HORIZON near Touros.
# Found Bora-Bora Pearl Beach Resort & Spa near Faanui.
# Found Hotel Narayan Avezika Comfort near Dwarka.
# Found Super 8 by Wyndham Swan River MB near Swan River.
# Found Hilo Hawaiian Hotel near Hilo.
# Found Paris Plaza near Elliot Lake.
# Found JABIR HOTEL near Bandarbeyla.
# Found Mini Central near Victoria.
# Found Guesthouse Nara Komachi near Nara.
# Found Guest Hotel near Manggar.
# Found Cititel Penang near Georgetown.
# Hotel not found... skipping Georgetown... skipping.
# Found Sheraton Kauai Coconut Beach Resort near Kapaa.
# Found Tiara Labuan Hotel near Labuan.
# Hotel not found... skipping Labuan... skipping.
# Found Tateyama Seaside Hotel near Tateyama.
# Found Casa Laguna, Bed & Breakfast near Guerrero Negro.
# Found castelo pizzaria near Acarau.
# Found National 9 Inn - Gillette WY near Gillette.
# Found Finch Bay Galapagos Hotel near Puerto Ayora.
# Hotel not found... skipping Puerto Ayora... skipping.
# Found SEGAYA PROPERTY near Dingle.
# Found Motel 6 Wendover, UT near West Wendover.
# Found Niyama Private Islands Maldives near Kudahuvadhoo.
# Found Heritage Park Hotel near Honiara.
# Hotel not found... skipping Honiara... skipping.
# Found Hampton Inn & Suites Show Low-Pinetop near Show Low.
# Found Hospedaje Henriquez near Bani.
# Found Kost Pria near Meulaboh.
# Found Sheraton Okinawa Sunmarina Resort near Ishikawa.
# Found Ricácio Hotel near Almeirim.
# Found Batalla’s Lodging House near Balabac.
# Found Xiushui Hotel near Yining.
# Hotel not found... skipping Yining... skipping.
# Found Hotel Marilu near Vila Do Maio.
# Found Pousada das Palmeiras near Posse.
# Found Hua Ling Grand Hotel Urumqi near Urumqi.
# Found Le Pilotis near Kousseri.
# Found Al Waddan Hotel near Tripoli.
# Found Tibesti Hotel near Benghazi.
# Found Courtyard by Marriott Boise West/Meridian near Meridian.
# Found Posada Turistica Manapiare near Puerto Ayacucho.
# Found Hoa Dao Hotel near Hoa Binh.
# Found Auki Motel near Auki.
# Found Carlito's Hostel near Santa Rita Do Sapucai.
# Found Kelly Inn & Suites near Mitchell.
# Found Hotel Den Helder near Den Helder.
# Hotel not found... skipping Den Helder... skipping.
# Found Luz del Sol near Alamos.
# Found Dibbo areaمنطقة دبو near Kutum.
# Found Gostinitsa Imperiya near Georgiyevka.
# Found Nuli Sapi near Samarai.
# Found Bungalow 63 near Hambantota.
# Found Shimoda Tokyu Hotel near Shimoda.
# Found Eng Hiirey House near Odweyne.
# Found Ephira Hotel near Corinto.
# Found Macs near Russell.
# Found Fengshui Residence near Port-Gentil.
# Found UN Humanitarian Hub near Bama.
# Found Style Homes Holiday Inn near Methala.
# Hotel not found... skipping Methala... skipping.
# Found Pir hos near Artyom.
# Found Osprey Beach Hotel near Cockburn Town.
# Found Bloc D tazoumbirt (amar) near Tigzirt.
# Found ZINGARA 76ft Catamaran, full crew-all included near Road Town.
# Found Flat Quatro Rodas Olinda near Olinda.
# Found Best Western Angus Inn near Great Bend.
# Found Motel Le Caribou near Matagami.
# Found HAMDAN PLAZA HOTEL SALALAH, an HTG Hotel near Salalah.
# Found Mugan Park Hotel near Sabirabad.
# Found ورشة الحضيري لاكترونات وخدمات النت near Suluq.
# Found Delong Fortune Hotel near Yueyang.
# Found Grand Vilia Hotel near Tual.
# Found Hôtel Abda near Asfi.
# Found Mercure Padang near Padang.
# Found งานแต่ง Murnee - Wahid near Yala.
# Found Seagulls Inn Namatani near Namatanai.
# Found Seaside Resort near Vung Tau.
# Found Bonifacio Lodge near Pandan.
# Found Paradise Hotel near Wanning.
# Found Quitanda santos near Ibipeba.
# Hotel not found... skipping Ibipeba... skipping.
# Found Baza Otdykha "Dacha" near Arkhangelskaya.
# Found hotel la terminal near Ixtapa.
# Found Euronova Freezer near Kattivakkam.
# Found Hotel do Campo near Ponta Do Sol.
# Found Meadow Brook Mobile Estates near Huron.
# Hotel not found... skipping Huron... skipping.
# Found Casa Dora, Bubaque near Bubaque.
# Found Hotel Branco I near Praia Da Vitoria.
# Found Jinliang Hotel near Mengcheng.
# Found Hotel Curuça near Curuca.
# Found Caycay future beach resort near Tagusao.
# Found sekretariat IKA STAIN near Sampang.
# Found Hotel Festival Plaza Rosarito near Rosarito.
# Found Nilawar Palace near Bhatkal.
# Found Kay-Vee Lodge Ltd near Hornepayne.
# Found Green leaf near Kavaratti.
# Found Jebinrio home near Manavalakurichi.
# Found Rendez-vous Des ChasseursD near Lekoni.
# Found Fuente del Guania Hotel de Lujo near Inirida.
# Found OYO 598 Peony Hotel near Cam Ranh.
# Found Pousada Camboinha near Cabedelo.
# Found Hôtel de l'ocean near Biarritz.
# Hotel not found... skipping Biarritz... skipping.
# Found Sand Canyon National 9 Inn near Cortez.
# Found Curubo Hotel near Garowe.
# Found Pumpkinn B&B near Port Elgin.
# Found Ted McQuinn Trust near Bud.
# Found Maringe Lagoon Lodge near Buala.
# Found امياس للصرافة near Jadu.
# Found Northland Motor Hotel near La Ronge.
# Found Eaka Hotel Hengshui Railway Station Branch near Hengshui.
# Found Hotel Crown Hills Nakamura near Nakamura.
# Found Hotel Lorenzana near Cantaura.
# Hotel not found... skipping Cantaura... skipping.
# Found Planta Hotel & Residences near Bacolod.
# Found Leumerus Bungalows near Sola.
# Found Guest Hôtel near Kasongo.
# Found Hotel Posada San Jose near Pochutla.
# Found Marom Hotel Haifa מלון מרום near Tirat Karmel.
# Found Maitai Lapita Village Huahine near Fare.

# %%
len(hotel_df)
# Out:
# 258

# %%
# 7. Drop the rows where there is no Hotel Name.
hotel_df = hotel_df.dropna()
hotel_df.head(10)
# Out:
#              City Country  Max Temp Current Description      Lat       Lng  \
# 8            Naze      JP     79.72     overcast clouds  28.3667  129.4833
# 19   La Primavera      CO     78.58       moderate rain   5.4906  -70.4092
# 22        Damghan      IR     88.72           clear sky  36.1683   54.3480
# 33        Batalha      BR     80.58    scattered clouds  -9.6778  -37.1247
# 34  Kota Kinabalu      MY     78.78          light rain   5.9749  116.0724
# 35    Salinopolis      BR     82.72    scattered clouds  -0.6136  -47.3561
# 38         Atuona      PF     78.17       broken clouds  -9.8000 -139.0333
# 41        Kavieng      PG     82.53     overcast clouds  -2.5744  150.7967
# 44         Touros      BR     82.44    scattered clouds  -5.1989  -35.4608
# 45         Faanui      PF     77.20    scattered clouds -16.4833 -151.7500
#
#                             Hotel Name
# 8                       Shishime Hotel
# 19           La Riviera Hotel Colonial
# 22       خوابگاه اساتيد دانشگاه دامغان
# 33             Pousada Solar do Sertão
# 34                   Gaya Centre Hotel
# 35  Salinas Park Resort Maçarico AP101
# 38                         Villa Enata
# 41                 Nusa Island Retreat
# 44                     INN NEW HORIZON
# 45  Bora-Bora Pearl Beach Resort & Spa

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>

"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.8)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
